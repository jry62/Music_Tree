# %%
# 1. import the data
# 2. Clean the Data
# 3. Split the data into training/test sets
# 4. create a model
# 5. Train the model
# 6. Make predictions
# 7. Evaluate and imporove

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mdf = pd.read_csv('musicmusic.csv')
mdf.shape
# Out:
# (18, 3)

# %%
mdf.describe()
# Out:
#              age     gender
# count  18.000000  18.000000
# mean   27.944444   0.500000
# std     5.127460   0.514496
# min    20.000000   0.000000
# 25%    25.000000   0.000000
# 50%    28.000000   0.500000
# 75%    31.000000   1.000000
# max    37.000000   1.000000

# %%
mdf.values
# Out:
# array([[20, 1, 'HipHop'],
#        [23, 1, 'HipHop'],
#        [25, 1, 'HipHop'],
#        [26, 1, 'Jazz'],
#        [29, 1, 'Jazz'],
#        [30, 1, 'Jazz'],
#        [31, 1, 'Classical'],
#        [33, 1, 'Classical'],
#        [37, 1, 'Classical'],
#        [20, 0, 'Dance'],
#        [21, 0, 'Dance'],
#        [25, 0, 'Dance'],
#        [26, 0, 'Acoustic'],
#        [27, 0, 'Acoustic'],
#        [30, 0, 'Acoustic'],
#        [31, 0, 'Classical'],
#        [34, 0, 'Classical'],
#        [35, 0, 'Classical']], dtype=object)

# %%
# must allocate 70-80% of data for training and other for testing
from sklearn.model_selection import train_test_split

X = mdf.drop(columns=['genre'])
y = mdf['genre']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
# decison tree from skelearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import joblib


# model = DecisionTreeClassifier()
# model.fit(X_train, y_train)


joblib.dump(model, 'music_rec.joblib')
# Out:
# ['music_rec.joblib']

# %%
model = joblib.load('music_rec.joblib')
predictions = model.predict([[21,1]])
predictions
# Out:
# array(['HipHop'], dtype=object)

# %%
from sklearn import tree
import pydotplus

fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)

tree.plot_tree(model, 
                feature_names= ['age', 'gender'],
                class_names= sorted(y.unique()),
                label= 'all',
                rounded= True,
                filled= True)
fig.savefig('MusicTree.png')
